# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.data_loader import load_data
from src.feature_engineering import add_features
from src.model_compare import evaluate_models

train, test = load_data()
train = add_features(train)
test  = add_features(test)

results = evaluate_models(train)
print("Model Karşılaştırma Sonuçları:")
for model, metrics in results.items():
    print(f"{model}: {metrics}")
# Out:
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:52:57] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:52:57] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:52:57] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:52:58] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:52:58] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:52:58] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:52:58] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:52:58] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:52:58] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\xgboost\training.py:183: UserWarning: [11:52:58] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# Model Karşılaştırma Sonuçları:
# LogisticRegression: {'accuracy': np.float64(0.828278199736363), 'f1': np.float64(0.7682390889931956)}
# RandomForest: {'accuracy': np.float64(0.8114430983616847), 'f1': np.float64(0.7516682340245986)}
# GradientBoosting: {'accuracy': np.float64(0.8406189190885694), 'f1': np.float64(0.7790256557168321)}
# XGBoost: {'accuracy': np.float64(0.8507124474295399), 'f1': np.float64(0.795909176763465)}
# LightGBM: {'accuracy': np.float64(0.8159123721047015), 'f1': np.float64(0.7589019765146494)}
# c:\Users\Emre\miniconda3\envs\VeriBilimi\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
