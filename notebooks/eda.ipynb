# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath(".."))  # notebooks klasöründen bir üst dizini ekle
from src.data_loader import load_data
from src.eda_plots import plot_categorical, plot_numerical

# Veriyi yükle
train, test = load_data()

# 1) Cinsiyet - hayatta kalma ilişkisi
plot_categorical(train, "Sex")

# 2) Pclass - hayatta kalma ilişkisi
plot_categorical(train, "Pclass")

# 3) Embarked - hayatta kalma ilişkisi
plot_categorical(train, "Embarked")

# 4) Age dağılımı
plot_numerical(train, "Age")

# 5) Fare dağılımı
plot_numerical(train, "Fare")

# 6) Yeni özellik: FamilySize
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
plot_numerical(train, "FamilySize")
# Out:
# c:\Users\Emre\Desktop\Titanic_ML\src\eda_plots.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y=target, data=df, ci=None)
# c:\Users\Emre\Desktop\Titanic_ML\src\eda_plots.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y=target, data=df, ci=None)
# c:\Users\Emre\Desktop\Titanic_ML\src\eda_plots.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col, y=target, data=df, ci=None)
