# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.data_loader import load_data
from src.feature_engineering import add_features
from src.modeling import evaluate_model

train, test = load_data()

# Feature engineering
train = add_features(train)
test  = add_features(test)

results = evaluate_model(train)
print("Feature Engineering sonrası sonuçlar:")
print(results)
# Out:
# Feature Engineering sonrası sonuçlar:
# {'accuracy_mean': np.float64(0.828278199736363), 'accuracy_std': np.float64(0.006845449035557786), 'f1_mean': np.float64(0.7682390889931956), 'f1_std': np.float64(0.011861275425582655)}
