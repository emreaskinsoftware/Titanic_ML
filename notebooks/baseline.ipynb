# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.data_loader import load_data
from src.modeling import evaluate_model

# Veriyi yükle
train, test = load_data()

# Feature engineering: FamilySize
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"]  = test["SibSp"] + test["Parch"] + 1

# Modeli değerlendir
results = evaluate_model(train)
print("Baseline Logistic Regression Sonuçları:")
print(results)
# Out:
# Baseline Logistic Regression Sonuçları:
# {'accuracy_mean': np.float64(0.8013495700207145), 'accuracy_std': np.float64(0.01094886536642612), 'f1_mean': np.float64(0.7275274788846465), 'f1_std': np.float64(0.020151997106319514)}
